# %% [markdown]
# # Simple linear regression - Exercise

# %% [markdown]
# You are given a real estate dataset.
#
# Real estate is one of those examples that every regression course goes through as it is extremely easy to understand and there is a (almost always) certain causal relationship to be found.
#
# The data is located in the file: 'real_estate_price_size.csv'.
#
# You are expected to create a simple linear regression (similar to the one in the lecture), using the new data.
#
# Apart from that, please:
# -  Create a scatter plot (with or without a regression line)
# -  Calculate the R-squared
# -  Display the intercept and coefficient(s)
# -  Using the model make a prediction about an apartment with size 750 sq.ft.
#
# Note: In this exercise, the dependent variable is 'price', while the independent variable is 'size'.
#
# Good luck!

# %% [markdown]
# ## Import the relevant libraries

# %%
# 3For these lessons we will need NumPy, pandas, matplotlib and seaborn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# and of course the actual regression (machine learning) module
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Load the data

# %%
data=pd.read_csv("real_estate_price_size.csv")
data.head()
# Out:
#         price     size
# 0  234314.144   643.09
# 1  228581.528   656.22
# 2  281626.336   487.29
# 3  401255.608  1504.75
# 4  458674.256  1275.46

# %%
data.shape
# Out:
# (100, 2)

# %% [markdown]
# ## Create the regression

# %% [markdown]
# ### Declare the dependent and the independent variables

# %%
#Declarando la variable independiente
X=data['size']
X=np.array(X)
X=X.reshape(-1,1)
X.shape

#Declarando la variable dependiente
Y=data['price']
Y.shape
# Out:
# (100,)

# %% [markdown]
# ### Explore the data

# %%
X.shape
# Out:
# (100, 1)

# %% [markdown]
# ### Transform the inputs into a matrix (2D object)

# %%
#Ya transformado el input en un array 2D

# %%
### Regression itself

# %%
reg=LinearRegression()
reg.fit(X, Y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Calculate the R-squared

# %%
reg.score(X, Y)
# Out:
# 0.7447391865847587

# %% [markdown]
# ### Find the intercept

# %%
reg.intercept_
# Out:
# np.float64(101912.60180122912)

# %% [markdown]
# ### Find the coefficients

# %%
reg.coef_
# Out:
# array([223.17874259])

# %%
m=reg.coef_[0]
b=reg.intercept_
print(f"la funcion de esta regresion lineal es la sig f(x)={round(b,2)} + {round(m,2)}*X")
x1=750
y1=b+m*x1
print(y1)
# Out:
# la funcion de esta regresion lineal es la sig f(x)=101912.6 + 223.18*X
# 269296.6587471847

# %% [markdown]
# ### Making predictions
#
# You find an apartment online with a size of 750 sq.ft.
#
# All else equal what should be its price according to the model?

# %%
x_1=np.array(750)
x_1_2D=x_1.reshape(-1,1)
x_1_2D.shape

y1_predicted=reg.predict(x_1_2D)
print(y1_predicted)
data['predicted']=reg.predict(X)
print(list(data))
data=data[['size','price','predicted']]
data.head()
# Out:
# [269296.65874718]
# ['size', 'price', 'predicted']
#       size       price      predicted
# 0   643.09  234314.144  245436.619376
# 1   656.22  228581.528  248366.956267
# 2   487.29  281626.336  210665.371280
# 3  1504.75  401255.608  437740.814720
# 4  1275.46  458674.256  386568.160831

# %%
plt.scatter(X,Y)
plt.plot(X, reg.predict(X))
